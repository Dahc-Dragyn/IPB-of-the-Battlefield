# %%
# Byte-compiled / optimized / DLL files
__pycache__/
*.py[cod]
*$py.class

# Virtual environments
env/
venv/
.venv/

# Jupyter Notebook checkpoints
.ipynb_checkpoints/

# Logs
*.log
*.out
*.txt

# OS generated files
.DS_Store
Thumbs.db

# Model weights
*.h5
*.hdf5
*.pkl
*.joblib
*.pt

# Data files
*.csv
*.parquet
*.json
data/terrain/*.tif  # Example for terrain data

# Environment and package files
.env
*.yaml
*.yml
Pipfile
Pipfile.lock

# IDE specific
.idea/
.vscode/
*.sublime-workspace
*.sublime-project

# Compiled C extensions
*.so

# Backup files
*.bak
*.swp
*.tmp

# Unit test / Coverage reports
htmlcov/
.tox/
.coverage
.cache/
.nox/
.pytest_cache/
